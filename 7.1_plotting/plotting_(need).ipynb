# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 A simple plot

# %% [markdown]
# ## 1.1 Let’s look at some code.

# %% [markdown]
# ### Things to note

# %%
from matplotlib import pyplot as plt

# %%
#creating a line plot using matplotlib

x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12] #y_1 and y_2 represent different sets of y values.
y_2 = [0, 3, 6, 9, 12, 15, 18]

plt.plot(x, y_1, label = 'Y values', color='red', linestyle='dashed') #plot the y_1 against x.

plt.xlabel('x-values') #add labels to the x-axis, calling it "x-axis"
plt.ylabel('y-values') #add labels to the y-axis, calling it "y-axis"
plt.title('X vs Y') #set title of the plot as "X vs Y".
plt.grid(alpha=.25) #adds gridlines to the plot with low opacity (0.25), making the gridlines faint
plt.legend(loc='upper left') #adds a legend to the plot, positioned in the upper left corner. change can to lower left as well

#If you wanted to plot y_2 as well, you would need another plt.plot() call.

plt.show()

# %%
#compare this graph with the one in the cell below. both should generate the same result using long forms and abbreviations respectively.

plt.plot(x, y_1, color='red', linestyle='dashed', linewidth=2)

# %%
plt.plot(x, y_1, c='red', ls='dashed', lw=2)

# %%
plt.plot(x, y_1, y_2) #keeping it simple and plot using default values for the styling parameters.

# %%
#plt.plot(x, y_1, color='red', linestyle='dashed', linewidth=2)

plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed')

plt.plot(x, y_2, label='Y2 values', color='blue')

plt.title('X vs Y')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# ## 1.2 Adding another plot

# %% [markdown]
# ## 1.3 Yet another plot but with error bars

# %%
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = .1, 0.75

plt.plot(x, y_1, label='Y1 values', color='red', linestyle='dashed',)
plt.plot(x, y_2, label='Y2 values', color='blue', )
plt.errorbar(x, y_3, xerr=x_error, yerr=y_error, label="Y3 with errors", color="green")
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='upper left')

# %% [markdown]
# # 2 Better with NumPy

# %%
import numpy as np

x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

np_x = np.array(x)
np_y_1 = np.array(y_1)
np_y_2 = np.array(y_2)

plt.plot(np_x, np_y_1, color='red', linestyle='dashed', label='Y values')
plt.plot(np_x, np_y_2, color='blue', label='Y2 values')

# %% [markdown]
# ## 2.1 Adding mathematical functions

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])

x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2', color='red', linestyle='dashed')
plt.plot(x, sin_x, label='sin(x)', color='blue')
plt.legend()

# %% [markdown]
# ## We need another axis!

# %%
x = np.array([0, 1, 2, 3, 4, 5, 6])
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2', color='red', linestyle='dashed')
plt.legend(loc='lower left') #legend for y-axis 1

plt.twinx() #creates a new y-axis for the plots that comes after

plt.plot(x, sin_x, label='sin(x)', color='blue', )
plt.legend(loc='lower right') #legend for y-axis 2

# %% [markdown]
# ### Things to note

# %%
x = np.linspace(0, 6, 100) #increased number of data points, as a result the curve for sin(x) now looks a lot better!
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2', color='red', linestyle='dashed')
plt.legend(loc='lower left') #legend for y-axis 1

plt.twinx() #creates a new y-axis for the plots that comes after

plt.plot(x, sin_x, label='sin(x)', color='blue', )
plt.legend(loc='lower right') #legend for y-axis 2

# %% [markdown]
# # 3 Saving to disc

# %%
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, label='x^2', color='red', linestyle='dashed')
plt.legend(loc='lower left')
plt.twinx()
plt.plot(x, sin_x, label='sin x', color='blue')
plt.legend(loc='lower right')

plt.savefig('highres-simple-plot.png', dpi=300) #printing a file with the same name will overwrite the previous one. be careful with this if you want to keep your previous images!

# %%
plt.savefig('highres-simple-plot.png', dpi=300) #shouldn't put in a new cell as this will just save an empty image.

# %% [markdown]
# # 4 A real example: Global Warming

# %% [markdown]
# ## 4.1 Plotting data from files

# %%
plt.style.use('fivethirtyeight')

file_url = 'https://berkeley-earth-temperature.s3.us-west-1.amazonaws.com/Global/Complete_TAVG_daily.txt'
data = np.loadtxt(file_url, skiprows=23)
plt.plot(data[:,1], data[:,-1], alpha=0.5)

# %%
data = np.loadtxt('Complete_TAVG_daily.txt',
                   skiprows=24)
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.ylim([-8, 8])

# %%
file_url = ''
data=np.loadtxt(file_url, skiprows=23)
plt.plot(data[:1],data[:,-1], alpha=0.5)

# %% [markdown]
# ## 4.2 Styles

# %% [markdown]
# ### xkcd!

# %%
plt.xkcd()

# %% [markdown]
# ### Resetting styles

# %%
plt.style.use('default')
